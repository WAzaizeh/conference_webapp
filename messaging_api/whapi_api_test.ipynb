# %%
import requests

url = "https://gate.whapi.cloud/groups?count=20"

headers = {
    "accept": "application/json",
    "authorization": "Bearer ZNPfZIGftJzhkjxP0BukACkHwCkVljG7"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"groups":[{"id":"120363306411083905@g.us","name":"MAS CYP Con App ","type":"group","timestamp":1724348837,"not_spam":true,"last_message":{"id":"OohSen2393pu2Q-kqEBq53KGp_IgQ-A8QLMs8","type":"text","chat_id":"120363306411083905@g.us","from":"16173970127","from_me":false,"from_name":"Sara","source":"mobile","timestamp":1724348837,"text":{"body":"alright so since most seem to agree about scenario two for this need I can start with stylizing inshaAllah soon\n\nbut I need the following content to help bring it to life (even if not all info is confirmed):\n\n- conference poster (even if placeholder) \n- ⁠conference slogan \n- ⁠cyp logo \n- ⁠description of the conference (for the about page) \n- ⁠name of the speakers and high quality images of the speakers \n- ⁠description of the speakers"}},"participants":[{"id":"13059009336","rank":"member"},{"id":"13475673343","rank":"member"},{"id":"14692675797","rank":"member"},{"id":"16173970127","rank":"member"},{"id":"16302172778","rank":"member"},
# ...

# %%
import json
groups_list = json.loads(response.text)
groups_list
# Out:
# {'groups': [{'id': '120363306411083905@g.us',
#    'name': 'MAS CYP Con App ',
#    'type': 'group',
#    'timestamp': 1724348837,
#    'not_spam': True,
#    'last_message': {'id': 'OohSen2393pu2Q-kqEBq53KGp_IgQ-A8QLMs8',
#     'type': 'text',
#     'chat_id': '120363306411083905@g.us',
#     'from': '16173970127',
#     'from_me': False,
#     'from_name': 'Sara',
#     'source': 'mobile',
#     'timestamp': 1724348837,
#     'text': {'body': 'alright so since most seem to agree about scenario two for this need I can start with stylizing inshaAllah soon\n\nbut I need the following content to help bring it to life (even if not all info is confirmed):\n\n- conference poster (even if placeholder) \n- \u2060conference slogan \n- \u2060cyp logo \n- \u2060description of the conference (for the about page) \n- \u2060name of the speakers and high quality images of the speakers \n- \u2060description of the speakers'}},
#    'participants': [{'id': '13059009336', 'rank': 'member'},
# ...

# %%
groups_list['groups'][12]['name']
# Out:
# 'Texas Hold Em 🤠'

# %%
test_group_id = groups_list['groups'][12]['id']
test_group_id
# Out:
# '120363284335164623@g.us'

# %%
import requests

url = "https://gate.whapi.cloud/messages/text"
message = 'Hello, this is a test message from the Whatsapp API'
payload = {
    "typing_time": 0,
    "to": test_group_id,
    "body": message
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer ZNPfZIGftJzhkjxP0BukACkHwCkVljG7"
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"sent":true,"message":{"id":"yqLt3NXEMbbA1rI-0gsBq53E9sv8zw-Awpgqzg","from_me":true,"type":"text","chat_id":"120363284335164623@g.us","timestamp":1724349146,"source":"api","device_id":32,"status":"pending","text":{"body":"Hello, this is a test message from the Whatsapp API"},"from":"13059009336"}}
